# %%
import pandas as pd

# %%
data_health = pd.io.stata.read_stata('Healthw15.dta')
data_health.to_csv('healthwave15.csv')

data_social = pd.io.stata.read_stata('socialILw15.dta')
data_social.to_csv('socialwave15.csv')

# %%
dhealth = pd.read_csv('healthwave15.csv')
dsocial = pd.read_csv('socialwave15.csv')

# %%
dhealth.shape
# Out:
# (5832, 210)

# %%
dsocial.shape
# Out:
# (5884, 438)

# %%
dsocial.tail()
# Out:
#       Unnamed: 0  nomem_encr   cs22o_m cs22o001 cs22o003 cs22o004 cs22o005  \
# 5879        5879    899794.0  202210.0      8.0       No       No       No
# 5880        5880    899891.0  202210.0      7.0       No       No      Yes
# 5881        5881    899908.0  202210.0      2.0       No       No       No
# 5882        5882    899923.0  202210.0      7.0       No       No       No
# 5883        5883    899928.0  202210.0      8.0      Yes       No       No
#
#      cs22o006 cs22o007 cs22o008  ...         cs22o410 cs22o411 cs22o412  \
# 5879      Yes       No       No  ...              2.0      4.0      4.0
# 5880      Yes       No      Yes  ...  1 certainly not      4.0      4.0
# 5881      Yes       No      Yes  ...              2.0      4.0      4.0
# 5882      Yes       No       No  ...  5 certainly yes      4.0      2.0
# 5883       No       No       No  ...              4.0      3.0      3.0
#
#              cs22o413         cs22o414    cs22o375  cs22o376    cs22o377  \
# ...

# %%
dhealth.tail()
# Out:
#       Unnamed: 0  nomem_encr   ch22o_m ch22o001  ch22o002         ch22o003  \
# 5827        5827    899794.0  202211.0   female      64.0     has paid job
# 5828        5828    899891.0  202211.0   female      31.0     has paid job
# 5829        5829    899908.0  202211.0     male      18.0  has no paid job
# 5830        5830    899923.0  202212.0     male      59.0     has paid job
# 5831        5831    899928.0  202211.0   female      77.0     has paid job
#
#        ch22o004         ch22o005 ch22o006 ch22o007  ...       ch22o250  \
# 5827       good         the same      6.0      6.0  ...            2.0
# 5828       good  somewhat better      8.0      8.0  ...  certainly not
# 5829  very good  somewhat poorer      8.0      7.0  ...            3.0
# 5830       good  somewhat better      5.0      5.0  ...            NaN
# 5831       good         the same      NaN      NaN  ...            2.0
#
#      ch22o251 ch22o252 ch22o253 ch22o254    ch22o255  ch22o256    ch22o257  \
# ...

# %%
new_df = dsocial.head(5)
new_df = new_df.append(dsocial.tail(5))
new_df
# Out:
# C:\Users\Mifa\AppData\Local\Temp\ipykernel_12396\2081553521.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(dsocial.tail(5))
#       Unnamed: 0  nomem_encr   cs22o_m              cs22o001 cs22o003  \
# 0              0    800001.0  202210.0                   8.0       No
# 1              1    800002.0  202210.0                   7.0      Yes
# 2              2    800009.0  202210.0  completely satisfied       No
# 3              3    800015.0  202210.0                   4.0      Yes
# 4              4    800028.0  202210.0                   9.0      Yes
# 5879        5879    899794.0  202210.0                   8.0       No
# 5880        5880    899891.0  202210.0                   7.0       No
# 5881        5881    899908.0  202210.0                   2.0       No
# 5882        5882    899923.0  202210.0                   7.0       No
# ...

# %%
newdf = dhealth.head(5)
newdf = newdf.append(dhealth.tail(5))
newdf
# Out:
# C:\Users\Mifa\AppData\Local\Temp\ipykernel_12396\2544087693.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newdf = newdf.append(dhealth.tail(5))
#       Unnamed: 0  nomem_encr   ch22o_m ch22o001  ch22o002         ch22o003  \
# 0              0    800001.0  202211.0     male      61.0     has paid job
# 1              1    800002.0  202211.0     male      45.0     has paid job
# 2              2    800009.0  202211.0     male      67.0     has paid job
# 3              3    800015.0  202211.0     male      60.0     has paid job
# 4              4    800028.0  202211.0     male      72.0  has no paid job
# 5827        5827    899794.0  202211.0   female      64.0     has paid job
# 5828        5828    899891.0  202211.0   female      31.0     has paid job
# 5829        5829    899908.0  202211.0     male      18.0  has no paid job
# ...
